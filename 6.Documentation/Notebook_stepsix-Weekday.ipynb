# %% [markdown]
# # Guided Capstone Step 6. Documentation

# %% [markdown]
# **The Data Science Method**
#
#
# 1.   Problem Identification
#
# 2.   Data Wrangling
#
# 3.   Exploratory Data Analysis
#
# 4.   Pre-processing and Training Data Development
#
# 5.  Modeling
#
# 6.   **Documentation**
#   * Review the Results
#   * Finalize Code
#   * Finalize Documentation
#   * Create a Project Report
#   * Create a Slide Deck for the Executive Audience

# %% [markdown]
# In this guided capstone we are going to revisit many of the actions we took in the previous guided capstone steps. This gives you the opportunity to practice the code you wrote to solve the questions in step 4 and 5.

# %% [markdown]
# **<font color='teal'> Start by loading the necessary packages and printing out our current working directory just to confirm we are in the correct project directory. </font>**

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import datetime
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from sklearn import linear_model
from sklearn.metrics import explained_variance_score, mean_absolute_error
# %matplotlib inline
os.getcwd()
# Out:
# '/Users/ktregier/Desktop/Springboard/Unit 6/Capstone1/6.Documentation'

# %% [markdown]
# ## Fit Models with Training Dataset

# %% [markdown]
# **<font color='teal'> Using sklearn fit the model you chose in Guided Capstone 5 on your training dataset. This includes: creating dummy features for states if you need them, scaling the data,and creating train and test splits before fitting the chosen model.Also, remember to generate a model performance score(MAE, or explained variance) based on the testing hold-out data set.</font>**

# %% [markdown]
# #### Best Model

# %%
file = '/Users/ktregier/Desktop/Springboard/Unit 6/Capstone1/3.EDA/step3.2_output.csv'
df = pd.read_csv(file, header=0, index_col=0)
montana = df.loc[df.state=='Montana']

X = df.drop(['AdultWeekday', 'Name', 'state', 'summit_elev'], axis=1)
y = df.AdultWeekday
scaler = preprocessing.StandardScaler().fit(X)
X_scaled=scaler.transform(X)
y = y.ravel()
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.25, random_state=1)
lm = linear_model.LinearRegression()
model = lm.fit(X_train, y_train)
y_pred = model.predict(X_test)
print("ESV: ", explained_variance_score(y_test, y_pred))
print("MAE: ", mean_absolute_error(y_test, y_pred))
print("Intercept: ", lm.intercept_)
# Out:
# ESV:  0.9194572488843922
# MAE:  5.524945603090985
# Intercept:  58.04916719096891

# %% [markdown]
# ## Review the results

# %% [markdown]
# **<font color='teal'> Now, let's predict the Big Mountain Weekend price with our model in order to provide a recommendation to our managers on how to price the `AdultWeekend` lift ticket. First we need to find the row for Big Mountain resort in our data using string contains or string matching.</font>**

# %%
bm = df[df['Name'].str.contains('Whitefish Mountain')]

# %% [markdown]
# **<font color='teal'> Prepare the Big Mountain resort data row as you did in the model fitting stage.</font>**

# %%
bmX = bm.drop(['AdultWeekday', 'Name', 'state', 'summit_elev'], axis=1)
#bmy = bm.AdultWeekend
#scaler = preprocessing.StandardScaler().fit(bmX)
bm_scaled = scaler.transform(bmX)
#bmy = bmy.ravel()

# %% [markdown]
# **<font color='teal'> Predict the Big Mountain resort `Adult Weekend` price and print it out.</font>** This is our expected price to present to management. Based on our model given the characteristics of the resort in comparison to other ski resorts and their unique characteristics.

# %%
bm_predict = model.predict(bm_scaled)
print("The expected Adult Weekday price at Big Mountain is $%f"  % bm_predict)
# Out:
# The expected Adult Weekday price at Big Mountain is $76.408520

# %% [markdown]
# **<font color='teal'> Print the Big Mountain resort actual `Adult Weekend` price.</font>**

# %%
print("The actual Adult Weekday price is $%f" % bm.AdultWeekend)
# Out:
# The actual Adult Weekday price is $81.000000

# %% [markdown]
# **<font color='teal'> As part of reviewing the results it is an important step to generate figures to visualize the data story. We can use the clusters we added to our data frame to create scatter plots for visualizing the Adult Weekend values compared to other characteristics. Run the example below to get you started and build two or three more figures to include in your data story telling.</font>**

# %%
plt.scatter(df['summit_elev'], df['vertical_drop'], c=df['clusters'], s=50, cmap='viridis', label ='clusters')
plt.scatter(bm['summit_elev'], bm['vertical_drop'], c='black', s=100)
plt.xlabel('summit_elev')
plt.ylabel('vertical_drop')
plt.title('summit_elev by vertical_drop by cluster')
plt.savefig('DaySummitxVerticalDrop.png',bbox_inches='tight')

# %%
plt.scatter(df['SkiableTerrain_ac'], df['Runs'], c=df['clusters'], s=50, cmap='viridis', label ='clusters')
plt.scatter(bm['SkiableTerrain_ac'], bm['Runs'], c='black', s=100)
plt.xlabel('SkiableTerrain_ac')
plt.ylabel('Runs')
plt.title('Acres of skiable terrain by number of runs by cluster')
plt.savefig('DayTerrainxRuns.png',bbox_inches='tight')

# %%
plt.scatter(df['Runs'], df['total_chairs'], c=df['clusters'], s=50, cmap='viridis', label ='clusters')
plt.scatter(bm['Runs'], bm['total_chairs'], c='black', s=100)
plt.xlabel('Runs')
plt.ylabel('total_chair')
plt.title('Number of runs by number of total chairs by cluster')
plt.savefig('DayRunsxChairs.png',bbox_inches='tight')

# %%
plt.scatter(df['Runs'], df['AdultWeekday'], c=df['clusters'], s=50, cmap='viridis', label ='clusters')
plt.scatter(bm['Runs'], bm['AdultWeekday'], c='black', s=100)
plt.xlabel('Runs')
plt.ylabel('AdultWeekday')
plt.title('Number of runs by current Adult Weekday price by cluster')
plt.savefig('DayRunsxWeekday.png',bbox_inches='tight')

# %%
plt.scatter(df['SkiableTerrain_ac'], df['AdultWeekday'], c=df['clusters'], s=50, cmap='viridis', label ='clusters')
plt.scatter(bm['SkiableTerrain_ac'], bm['AdultWeekday'], c='black', s=100)
plt.xlabel('SkiableTerrain_ac')
plt.ylabel('AdultWeekday')
plt.title('Skiable Terrain by Adult Weekday price by cluster')
plt.savefig('TerrainxWeekday.png',bbox_inches='tight')

# %%
plt.scatter(df['AdultWeekend'], df['AdultWeekday'], c=df['clusters'], s=50, cmap='viridis', label ='clusters')
plt.scatter(bm['AdultWeekend'], bm['AdultWeekday'], c='black', s=100)
plt.xlabel('AdultWeekend')
plt.ylabel('AdultWeekday')
plt.title('AdultWeekend by Adult Weekday price by cluster')
plt.savefig('WeekendxWeekday.png',bbox_inches='tight')

# %%
# Montana resorts
plt.scatter(montana['Runs'], montana['AdultWeekday'], c=montana['clusters'], s=50, cmap='viridis', label ='clusters')
plt.scatter(bm['Runs'], bm['AdultWeekday'], c='black', s=100)
plt.xlabel('Runs')
plt.ylabel('AdultWeekday')
plt.title('Montana Resorts - Number of runs by current Adult Weekday price')
plt.savefig('MontanaDayRunsxWeekday.png',bbox_inches='tight')

# %%
plt.scatter(montana['SkiableTerrain_ac'], montana['AdultWeekday'], c=montana['clusters'], s=50, cmap='viridis', label ='clusters')
plt.scatter(bm['SkiableTerrain_ac'], bm['AdultWeekday'], c='black', s=100)
plt.xlabel('SkiableTerrain_ac')
plt.ylabel('AdultWeekday')
plt.title('Montana Resorts - Skiable Terrain by current Adult Weekday price')
plt.savefig('MontanaTerrainxWeekday.png',bbox_inches='tight')

# %% [markdown]
# ## Finalize Code

# %% [markdown]
#  Making sure our code is well organized and easy to follow is an important step. This is the time where you need to review the notebooks and Python scripts you've created and clean them up so they are easy to follow and succinct in nature. Addtionally, we will also save our final model as a callable object using Pickle for future use in a data pipeline. Pickle is a module that serializes (and de-serializes) Python objects so that they can become executable objects like functions. It's used extensively in production environments where machine learning models are deployed on an industrial scale!**<font color='teal'> Run the example code below to save out your callable model. Notice that we save it in the models folder we created in our previous guided capstone step.</font>**

# %%
import pickle
s = pickle.dumps(model)
from joblib import dump, load
dump(model, 'models/regression_model_adultweekday.joblib')
# Out:
# ['models/regression_model_adultweekday.joblib']

# %% [markdown]
# ## Finalize Documentation

# %% [markdown]
# For model documentation, we want to save the model performance metrics as well as the features included in the final model. You could also save the model perfomance metrics and coefficients fo the other models you tried in case you want to refer to them later. **<font color='teal'> Create a dataframe containing the coefficients and the model performance metrics and save it out as a csv file, then upload it to your github repository.</font>**

# %%
# Create dataframe of coefficient results for this model
result = pd.DataFrame(abs(lm.coef_), X.columns, columns=['Final'])
coefficients = result.T
coefficients.index.name = "Model"
coefficients.head()
# Out:
#        vertical_drop     trams  fastEight  fastSixes  fastQuads      quad  \
# Model
# Final       0.345328  0.409425   0.611901   1.012701   0.309761  0.569638
#
#          triple    double   surface  total_chairs  ...  LongestRun_mi  \
# Model                                              ...
# Final  0.884426  0.124663  0.838357      0.393694  ...       0.290493
#
#        SkiableTerrain_ac  Snow Making_ac  daysOpenLastYear  yearsOpen  \
# Model
# Final           0.764201        1.678765           1.06362   0.135408
#
#        averageSnowfall  AdultWeekend  projectedDaysOpen  NightSkiing_ac  \
# Model
# Final         1.323757     20.917065           1.061498        0.768802
#
#        clusters
# Model
# Final  2.333662
#
# [1 rows x 22 columns]

# %%
#Create dataframe of model perforamance metrics for this model
performance = pd.DataFrame({"ESV": explained_variance_score(y_test, y_pred), "MAE":mean_absolute_error(y_test, y_pred)}, index=['Final'])
performance.index.name = "Model"
performance.head()
# Out:
#             ESV       MAE
# Model
# Final  0.919457  5.524946

# %%
#Merge the coefficients and performance metrics into a single dataframe
MountainModel = pd.concat([coefficients, performance], axis=1)
MountainModel.head()
# Out:
#        vertical_drop     trams  fastEight  fastSixes  fastQuads      quad  \
# Model
# Final       0.345328  0.409425   0.611901   1.012701   0.309761  0.569638
#
#          triple    double   surface  total_chairs  ...  Snow Making_ac  \
# Model                                              ...
# Final  0.884426  0.124663  0.838357      0.393694  ...        1.678765
#
#        daysOpenLastYear  yearsOpen  averageSnowfall  AdultWeekend  \
# Model
# Final           1.06362   0.135408         1.323757     20.917065
#
#        projectedDaysOpen  NightSkiing_ac  clusters       ESV       MAE
# Model
# Final           1.061498        0.768802  2.333662  0.919457  5.524946
#
# [1 rows x 24 columns]

# %%
MountainModel.to_csv("DayMountainModelMetrics.csv", index=True)
